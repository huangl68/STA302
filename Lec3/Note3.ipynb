# %%
plot(x = NA, type = 'n', ylim = c(0, 10), xlim = c(0, 10), xlab="", ylab='')
abline(a=2, b=0.5)
# Out:
# plot without title

# %%
x = c(0, 2, 4, 6, 8, 10)
y = c(0, 2, 4, 6, 8, 10)
plot(x, y)
abline(0, 1)
# Out:
# plot without title

# %%
x <- rnorm(n=1000,0,1)
y <- rnorm(n=1000,0,5)
boxplot(x, y)
# Out:
# plot without title

# %%
?rnorm

# %%
add <- function(a,b){
  to_return <- a+b
  return(to_return)
}

add(2,3)
# Out:
# [1] 5

# %%
mult <- function(a,b=1){
  to_return <- a*b
  return(to_return)
}

mult(2,2)
mult(3)
# Out:
# [1] 4
# [1] 3

# %%
fact <- function(a){
  to_return <-1
  while(a>1){
    to_return <- mult(to_return,a)
    a <- a-1
  }
  
  return(to_return)
}

factorial(5)
fact(5)
# Out:
# [1] 120
# [1] 120

# %%
yfun <- function(x,b0,b1){
  y <- b0+b1*x + runif(length(x),-5,5)
  return(y)
}

#When you define variable try to use short names with clear meaning
#add comment otherwise
n <- 50
b0 <- 5
b1 <- 2
x <- runif(n,0,20)

y <- yfun(x,b0,b1)

# %%
length(x)
# Out:
# [1] 50

# %%
plot(x,y,main="Our little simulated example")
plot(x,y,main="Our little simulated example",ylim=c(0,50),xlim=c(0,25))
# Out:
# Plot with title “Our little simulated example”
# Plot with title “Our little simulated example”

# %%
linreg <- function(x,y) {
  #Add a column of 1 to the vector to x
  X <- matrix(c(rep(1,length(x)),x),nrow=length(x),ncol=2)
  #Get the LSE estimates
  beta <- solve((t(X)%*%X))%*%t(X)%*%y
  return(beta)
}

# %%
beta <- linreg(x,y)
plot(x,y,main="Our little simulated example")
abline(a=beta[1],b=beta[2],col='red')
# Out:
# Plot with title “Our little simulated example”

# %%
summary(lm(y~x))
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.4292 -2.5041  0.1805  2.1261  4.7155
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.33307    0.80625   4.134 0.000142 ***
# x            2.14520    0.06884  31.164  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.729 on 48 degrees of freedom
# Multiple R-squared:  0.9529,	Adjusted R-squared:  0.9519
# F-statistic: 971.2 on 1 and 48 DF,  p-value: < 2.2e-16

# %%
yfun <- function(x,b0,b1){
  y <- b0+b1*x + runif(length(x),-20,20)
  return(y)
}

#When you define variable try to use short names with clear meaning
#add comment otherwise
n <- 50
b0 <- 5
b1 <- 2
x <- runif(n,0,20)

y <- yfun(x,b0,b1)

plot(x,y,main="Our little simulated example")
plot(x,y,main="Our little simulated example",ylim=c(0,50),xlim=c(0,25))
summary(lm(y~x))
# Out:
# Plot with title “Our little simulated example”
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -23.2676  -8.8044  -0.4865   9.2868  17.3681
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  11.0160     3.5287   3.122  0.00304 **
# x             1.5898     0.3256   4.883  1.2e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 11.64 on 48 degrees of freedom
# Multiple R-squared:  0.3319,	Adjusted R-squared:  0.318
# F-statistic: 23.85 on 1 and 48 DF,  p-value: 1.199e-05
# Plot with title “Our little simulated example”
